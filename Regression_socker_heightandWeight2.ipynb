# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanamjohn3-arch/git.demo/blob/main/Regression_socker_heightandWeight2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Datasets/SOCR-HeightWeight.csv")
df
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]

# %%
df.isna().sum()
# Out:
# Index             0
# Height(Inches)    0
# Weight(Pounds)    0
# dtype: int64

# %%
df.dtypes
# Out:
# Index               int64
# Height(Inches)    float64
# Weight(Pounds)    float64
# dtype: object

# %%
X = df.iloc[:,1:2]
X
# Out:
#        Height(Inches)
# 0            65.78331
# 1            71.51521
# 2            69.39874
# 3            68.21660
# 4            67.78781
# ...               ...
# 24995        69.50215
# 24996        64.54826
# 24997        64.69855
# 24998        67.52918
# 24999        68.87761
#
# [25000 rows x 1 columns]

# %%
y = df.iloc[:,-1]
y
# Out:
# 0        112.9925
# 1        136.4873
# 2        153.0269
# 3        142.3354
# 4        144.2971
#            ...
# 24995    118.0312
# 24996    120.1932
# 24997    118.2655
# 24998    132.2682
# 24999    124.8742
# Name: Weight(Pounds), Length: 25000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
slr.coef_
# Out:
# array([3.04085278])

# %%
slr.intercept_
# Out:
# np.float64(-79.69402312894555)

# %%
X_test.head()
# Out:
#        Height(Inches)
# 21492        69.66876
# 9488         66.53552
# 16933        67.36390
# 12604        68.69334
# 8222         67.43133

# %%
y_pred = slr.predict(X_test)
y_pred
# Out:
# array([132.1584195 , 122.63069793, 125.14967956, ..., 122.80773638,
#        122.19324085, 128.60454445])

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train)
plt.scatter(X_test,y_test)
plt.scatter(X_test,y_pred)
plt.plot(X_test,y_pred)
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.26604732615405746

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
print("Mean squared error is:",mean_absolute_error(y_test,y_pred))
print("Mean squared error is :",mean_squared_error(y_test,y_pred))
print("Root_mean_squared_error:",root_mean_squared_error(y_test,y_pred))
# Out:
# Mean squared error is: 8.073165906390226
# Mean squared error is : 101.73966139367002
# Root_mean_squared_error: 10.086608022207962

# %%
y_new = slr.predict([[72]])
y_new.item()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 139.24737714270935
