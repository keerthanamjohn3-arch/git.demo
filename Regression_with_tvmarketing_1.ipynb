# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanamjohn3-arch/git.demo/blob/main/Regression_with_tvmarketing_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Datasets/tvmarketing.csv")
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
df.dtypes
# Out:
# TV       float64
# Sales    float64
# dtype: object

# %%
X = df.iloc[:,0:1]
X
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y = df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.3,random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#coefficient value of x(that is ; m is the coefficient of x in y = mx+c)
slr.coef_
# Out:
# array([0.04812204])

# %%
# y-intercept value(ie;c)
slr.intercept_
# Out:
# np.float64(6.923519536059553)

# %%
X_test.head()
# Out:
#         TV
# 58   210.8
# 40   202.5
# 34    95.7
# 102  280.2
# 184  253.8

# %%
0.04812204*210.8+6.923519536059553
# Out:
# 17.067645568059554

# %%
0.04812204*202.5+6.923519536059553
# Out:
# 16.668232636059553

# %%
y_pred = slr.predict(X_test)
y_pred
# Out:
# array([17.06764591, 16.66823297, 11.52879892, 20.4073156 , 19.1368937 ,
#        20.57093054, 14.78184893, 15.62398466, 10.32093567, 17.2890073 ,
#        14.83959538, 10.25356482, 17.25532187, 12.20731971, 17.78947654,
#        12.97246017, 13.26119242, 20.91259704,  8.1554438 , 17.06283371,
#        11.75497252, 10.18619396,  8.13138278, 12.09182681, 12.35649804,
#        15.98971218,  8.99757953, 18.89628349, 14.95027608, 18.47762173,
#        18.46799732, 18.2081383 , 14.12738917, 15.11389102, 18.87703468,
#        15.82128503, 17.62586159, 13.15051172, 17.35637816,  7.86671155,
#         7.55391828, 11.2737521 ,  7.82340171, 16.74522823,  7.27481044,
#        14.01189627, 10.68666319, 17.89534503, 16.78853807, 17.96752809,
#        20.864475  , 12.84734286,  7.85708714, 15.71060434, 19.70473379,
#        14.89252963, 17.43818563,  8.12657058, 18.0926454 ,  8.99276733])

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train)
plt.scatter(X_test,y_test)
plt.scatter(X_test,y_pred)
#       0r to get a line of the best fit line
plt.plot(X_test,y_pred)
plt.xlabel("Amount spend in TV advertusement in (1000$)")
plt.ylabel("Sales REvenue in (M$)")
plt.show()

# %%
# r2 csore - used to get the accuracy score
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.575061860494331

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# MAE: 2.548375850318048
# MSE: 10.571057434656955
# RMSE: 3.251316261863333

# %%
y_new = slr.predict([[24]])
y_new.item()
# Out:
# 8.078448535130647

# %%
from sklearn.model
